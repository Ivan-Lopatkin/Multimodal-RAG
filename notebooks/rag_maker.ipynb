# %%
# !pip install --upgrade git+https://github.com/huggingface/transformers.git byaldi accelerate qwen_vl_utils pdf2image
# !sudo apt-get install -y poppler-utils
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-b95jcdf8
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-b95jcdf8
#   Resolved https://github.com/huggingface/transformers.git to commit c8c8dffbe45ebef0a8dba4a51024e5e5e498596b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: byaldi in /usr/local/lib/python3.10/dist-packages (0.0.5)
# Collecting byaldi
#   Using cached Byaldi-0.0.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: qwen_vl_utils in /usr/local/lib/python3.10/dist-packages (0.0.8)
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.10/dist-packages (1.17.0)
# Collecting mistralai
#   Downloading mistralai-1.2.5-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.48.0.dev0) (4.66.6)
# Collecting colpali-engine<0.4.0,>=0.3.4 (from byaldi)
#   Using cached colpali_engine-0.3.4-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from byaldi) (0.4.1)
# Requirement already satisfied: mteb==1.6.35 in /usr/local/lib/python3.10/dist-packages (from byaldi) (1.6.35)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from byaldi) (1.11.1.2)
# Requirement already satisfied: srsly in /usr/local/lib/python3.10/dist-packages (from byaldi) (2.4.8)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from byaldi) (2.5.1+cu121)
# Requirement already satisfied: datasets>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (3.1.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (4.0.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (1.13.1)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (3.2.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (13.9.4)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (0.5.6)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (2.10.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (4.12.2)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.10/dist-packages (from mteb==1.6.35->byaldi) (0.2.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: av in /usr/local/lib/python3.10/dist-packages (from qwen_vl_utils) (14.0.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from qwen_vl_utils) (10.4.0)
# Collecting httpx<0.28.0,>=0.27.0 (from mistralai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jsonpath-python<2.0.0,>=1.0.6 (from mistralai)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from mistralai) (2.8.2)
# Collecting typing-inspect<0.10.0,>=0.9.0 (from mistralai)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: gputil in /usr/local/lib/python3.10/dist-packages (from colpali-engine<0.4.0,>=0.3.4->byaldi) (1.4.0)
# Requirement already satisfied: peft<0.12.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from colpali-engine<0.4.0,>=0.3.4->byaldi) (0.11.1)
# INFO: pip is looking at multiple versions of colpali-engine to determine which version is compatible with other requirements. This could take a while.
# Requirement already satisfied: colpali-engine<0.4.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from byaldi) (0.3.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->mistralai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->mistralai) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.0.dev0) (2024.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->mteb==1.6.35->byaldi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic->mteb==1.6.35->byaldi) (2.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.2->mistralai) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.48.0.dev0) (2.2.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->byaldi) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->byaldi) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->byaldi) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->byaldi) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<0.10.0,>=0.9.0->mistralai)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from srsly->byaldi) (2.0.10)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.2.0->mteb==1.6.35->byaldi) (3.11.9)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mteb==1.6.35->byaldi) (3.5.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.28.0,>=0.27.0->mistralai) (1.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->byaldi) (3.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonlines->mteb==1.6.35->byaldi) (24.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mteb==1.6.35->byaldi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mteb==1.6.35->byaldi) (2.18.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.2.0->mteb==1.6.35->byaldi) (1.18.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mteb==1.6.35->byaldi) (0.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.2.0->mteb==1.6.35->byaldi) (2024.2)
# Downloading mistralai-1.2.5-py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 6.8 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.0 MB/s eta 0:00:00
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, jsonpath-python, typing-inspect, httpx, mistralai
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.0
#     Uninstalling httpx-0.28.0:
#       Successfully uninstalled httpx-0.28.0
# Successfully installed httpx-0.27.2 jsonpath-python-1.0.6 mistralai-1.2.5 mypy-extensions-1.0.0 typing-inspect-0.9.0
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.5).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
from byaldi import RAGMultiModalModel
from transformers import Qwen2VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info
import torch
from pdf2image import convert_from_path
import base64
import requests
from urllib.parse import urlencode
import zipfile
import io
import shutil
import os
from mistralai import Mistral

# %% [markdown]
# # Загрузка датасета

# %%
def load_data(url: str):
    base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'
    final_url = base_url + urlencode(dict(public_key=url))
    response = requests.get(final_url)

    download_url = response.json()['href']
    download_response = requests.get(download_url)

    zip = zipfile.ZipFile(io.BytesIO(download_response.content))
    zip.extractall('/content/')

# %%
load_data("https://disk.yandex.ru/d/_Y0wCNLTFevIBw")

# %%
with zipfile.ZipFile('/content/3 задача/RAG.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
listdir = os.listdir()

if 'pdf_files' in listdir:
    shutil.rmtree('pdf_files')

if 'docx_files' in listdir:
    shutil.rmtree('docx_files')

os.mkdir('pdf_files')
os.mkdir('docx_files')

listdir = os.listdir()

for filename in listdir:
    if filename.split('.')[-1] == 'pdf':
        os.rename(filename, 'pdf_files/' + filename)

    elif filename.split('.')[-1] == 'docx':
        os.rename(filename, 'docx_files/' + filename)

# %% [markdown]
# # Создание базы знаний

# %%
RAG = RAGMultiModalModel.from_pretrained("vidore/colqwen2-v1.0", index_root='/content/indices')
# Out:
# Verbosity is set to 1 (active). Pass verbose=0 to make quieter.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# `Qwen2VLRotaryEmbedding` can now be fully parameterized by passing the model config through the `config` argument. All other arguments will be removed in v4.46
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
RAG.index(
    input_path="/content/pdf_files/", # The path to your documents
    index_name='testindex1', # The name you want to give to your index. It'll be saved at `index_root/index_name/`.
    store_collection_with_index=False, # Whether the index should store the base64 encoded documents.
    overwrite=True # Whether to overwrite an index if it already exists. If False, it'll return None and do nothing if `index_root/index_name` exists.
)
# Out:
# Indexing file: /content/pdf_files/sr_ru_annual_report_pages_nornik_2022.pdf
# Added page 1 of document 0 to index.
# Added page 2 of document 0 to index.
# Added page 3 of document 0 to index.
# Added page 4 of document 0 to index.
# Added page 5 of document 0 to index.
# Added page 6 of document 0 to index.
# Added page 7 of document 0 to index.
# Added page 8 of document 0 to index.
# Added page 9 of document 0 to index.
# Added page 10 of document 0 to index.
# Added page 11 of document 0 to index.
# Added page 12 of document 0 to index.
# Added page 13 of document 0 to index.
# Added page 14 of document 0 to index.
# Added page 15 of document 0 to index.
# Added page 16 of document 0 to index.
# Added page 17 of document 0 to index.
# Added page 18 of document 0 to index.
# Added page 19 of document 0 to index.
# Added page 20 of document 0 to index.
# Added page 21 of document 0 to index.
# Added page 22 of document 0 to index.
# Added page 23 of document 0 to index.
# Added page 24 of document 0 to index.
# Added page 25 of document 0 to index.
# Added page 26 of document 0 to index.
# Added page 27 of document 0 to index.
# Added page 28 of document 0 to index.
# Added page 29 of document 0 to index.
# Added page 30 of document 0 to index.
# Added page 31 of document 0 to index.
# Added page 32 of document 0 to index.
# Added page 33 of document 0 to index.
# Added page 34 of document 0 to index.
# Added page 35 of document 0 to index.
# Added page 36 of document 0 to index.
# Added page 37 of document 0 to index.
# Added page 38 of document 0 to index.
# Added page 39 of document 0 to index.
# Added page 40 of document 0 to index.
# Added page 41 of document 0 to index.
# Added page 42 of document 0 to index.
# Added page 43 of document 0 to index.
# Added page 44 of document 0 to index.
# Added page 45 of document 0 to index.
# Added page 46 of document 0 to index.
# Added page 47 of document 0 to index.
# Added page 48 of document 0 to index.
# Added page 49 of document 0 to index.
# Added page 50 of document 0 to index.
# Added page 51 of document 0 to index.
# Added page 52 of document 0 to index.
# Added page 53 of document 0 to index.
# Added page 54 of document 0 to index.
# Added page 55 of document 0 to index.
# Added page 56 of document 0 to index.
# Added page 57 of document 0 to index.
# Added page 58 of document 0 to index.
# Added page 59 of document 0 to index.
# Added page 60 of document 0 to index.
# Added page 61 of document 0 to index.
# Added page 62 of document 0 to index.
# Added page 63 of document 0 to index.
# Added page 64 of document 0 to index.
# Added page 65 of document 0 to index.
# Added page 66 of document 0 to index.
# Added page 67 of document 0 to index.
# Added page 68 of document 0 to index.
# Added page 69 of document 0 to index.
# Added page 70 of document 0 to index.
# Added page 71 of document 0 to index.
# Added page 72 of document 0 to index.
# Added page 73 of document 0 to index.
# Added page 74 of document 0 to index.
# Added page 75 of document 0 to index.
# Added page 76 of document 0 to index.
# Added page 77 of document 0 to index.
# Added page 78 of document 0 to index.
# Added page 79 of document 0 to index.
# Added page 80 of document 0 to index.
# Added page 81 of document 0 to index.
# Added page 82 of document 0 to index.
# Added page 83 of document 0 to index.
# Added page 84 of document 0 to index.
# Added page 85 of document 0 to index.
# Added page 86 of document 0 to index.
# Added page 87 of document 0 to index.
# Added page 88 of document 0 to index.
# Added page 89 of document 0 to index.
# Added page 90 of document 0 to index.
# Added page 91 of document 0 to index.
# Added page 92 of document 0 to index.
# Added page 93 of document 0 to index.
# Added page 94 of document 0 to index.
# Added page 95 of document 0 to index.
# Added page 96 of document 0 to index.
# Added page 97 of document 0 to index.
# Added page 98 of document 0 to index.
# Added page 99 of document 0 to index.
# Added page 100 of document 0 to index.
# Added page 101 of document 0 to index.
# Added page 102 of document 0 to index.
# Added page 103 of document 0 to index.
# Added page 104 of document 0 to index.
# Added page 105 of document 0 to index.
# Added page 106 of document 0 to index.
# Added page 107 of document 0 to index.
# Added page 108 of document 0 to index.
# Added page 109 of document 0 to index.
# Added page 110 of document 0 to index.
# Added page 111 of document 0 to index.
# Added page 112 of document 0 to index.
# Added page 113 of document 0 to index.
# Added page 114 of document 0 to index.
# Added page 115 of document 0 to index.
# Added page 116 of document 0 to index.
# Added page 117 of document 0 to index.
# Added page 118 of document 0 to index.
# Added page 119 of document 0 to index.
# Added page 120 of document 0 to index.
# Added page 121 of document 0 to index.
# Added page 122 of document 0 to index.
# Added page 123 of document 0 to index.
# Added page 124 of document 0 to index.
# Added page 125 of document 0 to index.
# Added page 126 of document 0 to index.
# Added page 127 of document 0 to index.
# Added page 128 of document 0 to index.
# Added page 129 of document 0 to index.
# Added page 130 of document 0 to index.
# Added page 131 of document 0 to index.
# Added page 132 of document 0 to index.
# Added page 133 of document 0 to index.
# Added page 134 of document 0 to index.
# Added page 135 of document 0 to index.
# Added page 136 of document 0 to index.
# Added page 137 of document 0 to index.
# Added page 138 of document 0 to index.
# Added page 139 of document 0 to index.
# Added page 140 of document 0 to index.
# Added page 141 of document 0 to index.
# Added page 142 of document 0 to index.
# Added page 143 of document 0 to index.
# Added page 144 of document 0 to index.
# Added page 145 of document 0 to index.
# Added page 146 of document 0 to index.
# Added page 147 of document 0 to index.
# Added page 148 of document 0 to index.
# Added page 149 of document 0 to index.
# Added page 150 of document 0 to index.
# Added page 151 of document 0 to index.
# Added page 152 of document 0 to index.
# Added page 153 of document 0 to index.
# Added page 154 of document 0 to index.
# Added page 155 of document 0 to index.
# Added page 156 of document 0 to index.
# Added page 157 of document 0 to index.
# Added page 158 of document 0 to index.
# Added page 159 of document 0 to index.
# Added page 160 of document 0 to index.
# Added page 161 of document 0 to index.
# Added page 162 of document 0 to index.
# Added page 163 of document 0 to index.
# Added page 164 of document 0 to index.
# Added page 165 of document 0 to index.
# Added page 166 of document 0 to index.
# Added page 167 of document 0 to index.
# Added page 168 of document 0 to index.
# Added page 169 of document 0 to index.
# Added page 170 of document 0 to index.
# Added page 171 of document 0 to index.
# Added page 172 of document 0 to index.
# Added page 173 of document 0 to index.
# Added page 174 of document 0 to index.
# Added page 175 of document 0 to index.
# Added page 176 of document 0 to index.
# Added page 177 of document 0 to index.
# Added page 178 of document 0 to index.
# Added page 179 of document 0 to index.
# Added page 180 of document 0 to index.
# Added page 181 of document 0 to index.
# Added page 182 of document 0 to index.
# Added page 183 of document 0 to index.
# Added page 184 of document 0 to index.
# Added page 185 of document 0 to index.
# Added page 186 of document 0 to index.
# Added page 187 of document 0 to index.
# Added page 188 of document 0 to index.
# Added page 189 of document 0 to index.
# Added page 190 of document 0 to index.
# Added page 191 of document 0 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/responsible_supply_chain_report_rus.pdf
# Added page 1 of document 1 to index.
# Added page 2 of document 1 to index.
# Added page 3 of document 1 to index.
# Added page 4 of document 1 to index.
# Added page 5 of document 1 to index.
# Added page 6 of document 1 to index.
# Added page 7 of document 1 to index.
# Added page 8 of document 1 to index.
# Added page 9 of document 1 to index.
# Added page 10 of document 1 to index.
# Added page 11 of document 1 to index.
# Added page 12 of document 1 to index.
# Added page 13 of document 1 to index.
# Added page 14 of document 1 to index.
# Added page 15 of document 1 to index.
# Added page 16 of document 1 to index.
# Added page 17 of document 1 to index.
# Added page 18 of document 1 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/NN_CSO2021_RUS_03.03.2023.pdf
# Added page 1 of document 2 to index.
# Added page 2 of document 2 to index.
# Added page 3 of document 2 to index.
# Added page 4 of document 2 to index.
# Added page 5 of document 2 to index.
# Added page 6 of document 2 to index.
# Added page 7 of document 2 to index.
# Added page 8 of document 2 to index.
# Added page 9 of document 2 to index.
# Added page 10 of document 2 to index.
# Added page 11 of document 2 to index.
# Added page 12 of document 2 to index.
# Added page 13 of document 2 to index.
# Added page 14 of document 2 to index.
# Added page 15 of document 2 to index.
# Added page 16 of document 2 to index.
# Added page 17 of document 2 to index.
# Added page 18 of document 2 to index.
# Added page 19 of document 2 to index.
# Added page 20 of document 2 to index.
# Added page 21 of document 2 to index.
# Added page 22 of document 2 to index.
# Added page 23 of document 2 to index.
# Added page 24 of document 2 to index.
# Added page 25 of document 2 to index.
# Added page 26 of document 2 to index.
# Added page 27 of document 2 to index.
# Added page 28 of document 2 to index.
# Added page 29 of document 2 to index.
# Added page 30 of document 2 to index.
# Added page 31 of document 2 to index.
# Added page 32 of document 2 to index.
# Added page 33 of document 2 to index.
# Added page 34 of document 2 to index.
# Added page 35 of document 2 to index.
# Added page 36 of document 2 to index.
# Added page 37 of document 2 to index.
# Added page 38 of document 2 to index.
# Added page 39 of document 2 to index.
# Added page 40 of document 2 to index.
# Added page 41 of document 2 to index.
# Added page 42 of document 2 to index.
# Added page 43 of document 2 to index.
# Added page 44 of document 2 to index.
# Added page 45 of document 2 to index.
# Added page 46 of document 2 to index.
# Added page 47 of document 2 to index.
# Added page 48 of document 2 to index.
# Added page 49 of document 2 to index.
# Added page 50 of document 2 to index.
# Added page 51 of document 2 to index.
# Added page 52 of document 2 to index.
# Added page 53 of document 2 to index.
# Added page 54 of document 2 to index.
# Added page 55 of document 2 to index.
# Added page 56 of document 2 to index.
# Added page 57 of document 2 to index.
# Added page 58 of document 2 to index.
# Added page 59 of document 2 to index.
# Added page 60 of document 2 to index.
# Added page 61 of document 2 to index.
# Added page 62 of document 2 to index.
# Added page 63 of document 2 to index.
# Added page 64 of document 2 to index.
# Added page 65 of document 2 to index.
# Added page 66 of document 2 to index.
# Added page 67 of document 2 to index.
# Added page 68 of document 2 to index.
# Added page 69 of document 2 to index.
# Added page 70 of document 2 to index.
# Added page 71 of document 2 to index.
# Added page 72 of document 2 to index.
# Added page 73 of document 2 to index.
# Added page 74 of document 2 to index.
# Added page 75 of document 2 to index.
# Added page 76 of document 2 to index.
# Added page 77 of document 2 to index.
# Added page 78 of document 2 to index.
# Added page 79 of document 2 to index.
# Added page 80 of document 2 to index.
# Added page 81 of document 2 to index.
# Added page 82 of document 2 to index.
# Added page 83 of document 2 to index.
# Added page 84 of document 2 to index.
# Added page 85 of document 2 to index.
# Added page 86 of document 2 to index.
# Added page 87 of document 2 to index.
# Added page 88 of document 2 to index.
# Added page 89 of document 2 to index.
# Added page 90 of document 2 to index.
# Added page 91 of document 2 to index.
# Added page 92 of document 2 to index.
# Added page 93 of document 2 to index.
# Added page 94 of document 2 to index.
# Added page 95 of document 2 to index.
# Added page 96 of document 2 to index.
# Added page 97 of document 2 to index.
# Added page 98 of document 2 to index.
# Added page 99 of document 2 to index.
# Added page 100 of document 2 to index.
# Added page 101 of document 2 to index.
# Added page 102 of document 2 to index.
# Added page 103 of document 2 to index.
# Added page 104 of document 2 to index.
# Added page 105 of document 2 to index.
# Added page 106 of document 2 to index.
# Added page 107 of document 2 to index.
# Added page 108 of document 2 to index.
# Added page 109 of document 2 to index.
# Added page 110 of document 2 to index.
# Added page 111 of document 2 to index.
# Added page 112 of document 2 to index.
# Added page 113 of document 2 to index.
# Added page 114 of document 2 to index.
# Added page 115 of document 2 to index.
# Added page 116 of document 2 to index.
# Added page 117 of document 2 to index.
# Added page 118 of document 2 to index.
# Added page 119 of document 2 to index.
# Added page 120 of document 2 to index.
# Added page 121 of document 2 to index.
# Added page 122 of document 2 to index.
# Added page 123 of document 2 to index.
# Added page 124 of document 2 to index.
# Added page 125 of document 2 to index.
# Added page 126 of document 2 to index.
# Added page 127 of document 2 to index.
# Added page 128 of document 2 to index.
# Added page 129 of document 2 to index.
# Added page 130 of document 2 to index.
# Added page 131 of document 2 to index.
# Added page 132 of document 2 to index.
# Added page 133 of document 2 to index.
# Added page 134 of document 2 to index.
# Added page 135 of document 2 to index.
# Added page 136 of document 2 to index.
# Added page 137 of document 2 to index.
# Added page 138 of document 2 to index.
# Added page 139 of document 2 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/2_5366183129474161642.pdf
# Added page 1 of document 3 to index.
# Added page 2 of document 3 to index.
# Added page 3 of document 3 to index.
# Added page 4 of document 3 to index.
# Added page 5 of document 3 to index.
# Added page 6 of document 3 to index.
# Added page 7 of document 3 to index.
# Added page 8 of document 3 to index.
# Added page 9 of document 3 to index.
# Added page 10 of document 3 to index.
# Added page 11 of document 3 to index.
# Added page 12 of document 3 to index.
# Added page 13 of document 3 to index.
# Added page 14 of document 3 to index.
# Added page 15 of document 3 to index.
# Added page 16 of document 3 to index.
# Added page 17 of document 3 to index.
# Added page 18 of document 3 to index.
# Added page 19 of document 3 to index.
# Added page 20 of document 3 to index.
# Added page 21 of document 3 to index.
# Added page 22 of document 3 to index.
# Added page 23 of document 3 to index.
# Added page 24 of document 3 to index.
# Added page 25 of document 3 to index.
# Added page 26 of document 3 to index.
# Added page 27 of document 3 to index.
# Added page 28 of document 3 to index.
# Added page 29 of document 3 to index.
# Added page 30 of document 3 to index.
# Added page 31 of document 3 to index.
# Added page 32 of document 3 to index.
# Added page 33 of document 3 to index.
# Added page 34 of document 3 to index.
# Added page 35 of document 3 to index.
# Added page 36 of document 3 to index.
# Added page 37 of document 3 to index.
# Added page 38 of document 3 to index.
# Added page 39 of document 3 to index.
# Added page 40 of document 3 to index.
# Added page 41 of document 3 to index.
# Added page 42 of document 3 to index.
# Added page 43 of document 3 to index.
# Added page 44 of document 3 to index.
# Added page 45 of document 3 to index.
# Added page 46 of document 3 to index.
# Added page 47 of document 3 to index.
# Added page 48 of document 3 to index.
# Added page 49 of document 3 to index.
# Added page 50 of document 3 to index.
# Added page 51 of document 3 to index.
# Added page 52 of document 3 to index.
# Added page 53 of document 3 to index.
# Added page 54 of document 3 to index.
# Added page 55 of document 3 to index.
# Added page 56 of document 3 to index.
# Added page 57 of document 3 to index.
# Added page 58 of document 3 to index.
# Added page 59 of document 3 to index.
# Added page 60 of document 3 to index.
# Added page 61 of document 3 to index.
# Added page 62 of document 3 to index.
# Added page 63 of document 3 to index.
# Added page 64 of document 3 to index.
# Added page 65 of document 3 to index.
# Added page 66 of document 3 to index.
# Added page 67 of document 3 to index.
# Added page 68 of document 3 to index.
# Added page 69 of document 3 to index.
# Added page 70 of document 3 to index.
# Added page 71 of document 3 to index.
# Added page 72 of document 3 to index.
# Added page 73 of document 3 to index.
# Added page 74 of document 3 to index.
# Added page 75 of document 3 to index.
# Added page 76 of document 3 to index.
# Added page 77 of document 3 to index.
# Added page 78 of document 3 to index.
# Added page 79 of document 3 to index.
# Added page 80 of document 3 to index.
# Added page 81 of document 3 to index.
# Added page 82 of document 3 to index.
# Added page 83 of document 3 to index.
# Added page 84 of document 3 to index.
# Added page 85 of document 3 to index.
# Added page 86 of document 3 to index.
# Added page 87 of document 3 to index.
# Added page 88 of document 3 to index.
# Added page 89 of document 3 to index.
# Added page 90 of document 3 to index.
# Added page 91 of document 3 to index.
# Added page 92 of document 3 to index.
# Added page 93 of document 3 to index.
# Added page 94 of document 3 to index.
# Added page 95 of document 3 to index.
# Added page 96 of document 3 to index.
# Added page 97 of document 3 to index.
# Added page 98 of document 3 to index.
# Added page 99 of document 3 to index.
# Added page 100 of document 3 to index.
# Added page 101 of document 3 to index.
# Added page 102 of document 3 to index.
# Added page 103 of document 3 to index.
# Added page 104 of document 3 to index.
# Added page 105 of document 3 to index.
# Added page 106 of document 3 to index.
# Added page 107 of document 3 to index.
# Added page 108 of document 3 to index.
# Added page 109 of document 3 to index.
# Added page 110 of document 3 to index.
# Added page 111 of document 3 to index.
# Added page 112 of document 3 to index.
# Added page 113 of document 3 to index.
# Added page 114 of document 3 to index.
# Added page 115 of document 3 to index.
# Added page 116 of document 3 to index.
# Added page 117 of document 3 to index.
# Added page 118 of document 3 to index.
# Added page 119 of document 3 to index.
# Added page 120 of document 3 to index.
# Added page 121 of document 3 to index.
# Added page 122 of document 3 to index.
# Added page 123 of document 3 to index.
# Added page 124 of document 3 to index.
# Added page 125 of document 3 to index.
# Added page 126 of document 3 to index.
# Added page 127 of document 3 to index.
# Added page 128 of document 3 to index.
# Added page 129 of document 3 to index.
# Added page 130 of document 3 to index.
# Added page 131 of document 3 to index.
# Added page 132 of document 3 to index.
# Added page 133 of document 3 to index.
# Added page 134 of document 3 to index.
# Added page 135 of document 3 to index.
# Added page 136 of document 3 to index.
# Added page 137 of document 3 to index.
# Added page 138 of document 3 to index.
# Added page 139 of document 3 to index.
# Added page 140 of document 3 to index.
# Added page 141 of document 3 to index.
# Added page 142 of document 3 to index.
# Added page 143 of document 3 to index.
# Added page 144 of document 3 to index.
# Added page 145 of document 3 to index.
# Added page 146 of document 3 to index.
# Added page 147 of document 3 to index.
# Added page 148 of document 3 to index.
# Added page 149 of document 3 to index.
# Added page 150 of document 3 to index.
# Added page 151 of document 3 to index.
# Added page 152 of document 3 to index.
# Added page 153 of document 3 to index.
# Added page 154 of document 3 to index.
# Added page 155 of document 3 to index.
# Added page 156 of document 3 to index.
# Added page 157 of document 3 to index.
# Added page 158 of document 3 to index.
# Added page 159 of document 3 to index.
# Added page 160 of document 3 to index.
# Added page 161 of document 3 to index.
# Added page 162 of document 3 to index.
# Added page 163 of document 3 to index.
# Added page 164 of document 3 to index.
# Added page 165 of document 3 to index.
# Added page 166 of document 3 to index.
# Added page 167 of document 3 to index.
# Added page 168 of document 3 to index.
# Added page 169 of document 3 to index.
# Added page 170 of document 3 to index.
# Added page 171 of document 3 to index.
# Added page 172 of document 3 to index.
# Added page 173 of document 3 to index.
# Added page 174 of document 3 to index.
# Added page 175 of document 3 to index.
# Added page 176 of document 3 to index.
# Added page 177 of document 3 to index.
# Added page 178 of document 3 to index.
# Added page 179 of document 3 to index.
# Added page 180 of document 3 to index.
# Added page 181 of document 3 to index.
# Added page 182 of document 3 to index.
# Added page 183 of document 3 to index.
# Added page 184 of document 3 to index.
# Added page 185 of document 3 to index.
# Added page 186 of document 3 to index.
# Added page 187 of document 3 to index.
# Added page 188 of document 3 to index.
# Added page 189 of document 3 to index.
# Added page 190 of document 3 to index.
# Added page 191 of document 3 to index.
# Added page 192 of document 3 to index.
# Added page 193 of document 3 to index.
# Added page 194 of document 3 to index.
# Added page 195 of document 3 to index.
# Added page 196 of document 3 to index.
# Added page 197 of document 3 to index.
# Added page 198 of document 3 to index.
# Added page 199 of document 3 to index.
# Added page 200 of document 3 to index.
# Added page 201 of document 3 to index.
# Added page 202 of document 3 to index.
# Added page 203 of document 3 to index.
# Added page 204 of document 3 to index.
# Added page 205 of document 3 to index.
# Added page 206 of document 3 to index.
# Added page 207 of document 3 to index.
# Added page 208 of document 3 to index.
# Added page 209 of document 3 to index.
# Added page 210 of document 3 to index.
# Added page 211 of document 3 to index.
# Added page 212 of document 3 to index.
# Added page 213 of document 3 to index.
# Added page 214 of document 3 to index.
# Added page 215 of document 3 to index.
# Added page 216 of document 3 to index.
# Added page 217 of document 3 to index.
# Added page 218 of document 3 to index.
# Added page 219 of document 3 to index.
# Added page 220 of document 3 to index.
# Added page 221 of document 3 to index.
# Added page 222 of document 3 to index.
# Added page 223 of document 3 to index.
# Added page 224 of document 3 to index.
# Added page 225 of document 3 to index.
# Added page 226 of document 3 to index.
# Added page 227 of document 3 to index.
# Added page 228 of document 3 to index.
# Added page 229 of document 3 to index.
# Added page 230 of document 3 to index.
# Added page 231 of document 3 to index.
# Added page 232 of document 3 to index.
# Added page 233 of document 3 to index.
# Added page 234 of document 3 to index.
# Added page 235 of document 3 to index.
# Added page 236 of document 3 to index.
# Added page 237 of document 3 to index.
# Added page 238 of document 3 to index.
# Added page 239 of document 3 to index.
# Added page 240 of document 3 to index.
# Added page 241 of document 3 to index.
# Added page 242 of document 3 to index.
# Added page 243 of document 3 to index.
# Added page 244 of document 3 to index.
# Added page 245 of document 3 to index.
# Added page 246 of document 3 to index.
# Added page 247 of document 3 to index.
# Added page 248 of document 3 to index.
# Added page 249 of document 3 to index.
# Added page 250 of document 3 to index.
# Added page 251 of document 3 to index.
# Added page 252 of document 3 to index.
# Added page 253 of document 3 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/digital_production_5.pdf
# Added page 1 of document 4 to index.
# Added page 2 of document 4 to index.
# Added page 3 of document 4 to index.
# Added page 4 of document 4 to index.
# Added page 5 of document 4 to index.
# Added page 6 of document 4 to index.
# Added page 7 of document 4 to index.
# Added page 8 of document 4 to index.
# Added page 9 of document 4 to index.
# Added page 10 of document 4 to index.
# Added page 11 of document 4 to index.
# Added page 12 of document 4 to index.
# Added page 13 of document 4 to index.
# Added page 14 of document 4 to index.
# Added page 15 of document 4 to index.
# Added page 16 of document 4 to index.
# Added page 17 of document 4 to index.
# Added page 18 of document 4 to index.
# Added page 19 of document 4 to index.
# Added page 20 of document 4 to index.
# Added page 21 of document 4 to index.
# Added page 22 of document 4 to index.
# Added page 23 of document 4 to index.
# Added page 24 of document 4 to index.
# Added page 25 of document 4 to index.
# Added page 26 of document 4 to index.
# Added page 27 of document 4 to index.
# Added page 28 of document 4 to index.
# Added page 29 of document 4 to index.
# Added page 30 of document 4 to index.
# Added page 31 of document 4 to index.
# Added page 32 of document 4 to index.
# Added page 33 of document 4 to index.
# Added page 34 of document 4 to index.
# Added page 35 of document 4 to index.
# Added page 36 of document 4 to index.
# Added page 37 of document 4 to index.
# Added page 38 of document 4 to index.
# Added page 39 of document 4 to index.
# Added page 40 of document 4 to index.
# Added page 41 of document 4 to index.
# Added page 42 of document 4 to index.
# Added page 43 of document 4 to index.
# Added page 44 of document 4 to index.
# Added page 45 of document 4 to index.
# Added page 46 of document 4 to index.
# Added page 47 of document 4 to index.
# Added page 48 of document 4 to index.
# Added page 49 of document 4 to index.
# Added page 50 of document 4 to index.
# Added page 51 of document 4 to index.
# Added page 52 of document 4 to index.
# Added page 53 of document 4 to index.
# Added page 54 of document 4 to index.
# Added page 55 of document 4 to index.
# Added page 56 of document 4 to index.
# Added page 57 of document 4 to index.
# Added page 58 of document 4 to index.
# Added page 59 of document 4 to index.
# Added page 60 of document 4 to index.
# Added page 61 of document 4 to index.
# Added page 62 of document 4 to index.
# Added page 63 of document 4 to index.
# Added page 64 of document 4 to index.
# Added page 65 of document 4 to index.
# Added page 66 of document 4 to index.
# Added page 67 of document 4 to index.
# Added page 68 of document 4 to index.
# Added page 69 of document 4 to index.
# Added page 70 of document 4 to index.
# Added page 71 of document 4 to index.
# Added page 72 of document 4 to index.
# Added page 73 of document 4 to index.
# Added page 74 of document 4 to index.
# Added page 75 of document 4 to index.
# Added page 76 of document 4 to index.
# Added page 77 of document 4 to index.
# Added page 78 of document 4 to index.
# Added page 79 of document 4 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/2022_Annual_Report_of_PJSC_MMC_Norilsk_Nickel_rus.pdf
# Added page 1 of document 5 to index.
# Added page 2 of document 5 to index.
# Added page 3 of document 5 to index.
# Added page 4 of document 5 to index.
# Added page 5 of document 5 to index.
# Added page 6 of document 5 to index.
# Added page 7 of document 5 to index.
# Added page 8 of document 5 to index.
# Added page 9 of document 5 to index.
# Added page 10 of document 5 to index.
# Added page 11 of document 5 to index.
# Added page 12 of document 5 to index.
# Added page 13 of document 5 to index.
# Added page 14 of document 5 to index.
# Added page 15 of document 5 to index.
# Added page 16 of document 5 to index.
# Added page 17 of document 5 to index.
# Added page 18 of document 5 to index.
# Added page 19 of document 5 to index.
# Added page 20 of document 5 to index.
# Added page 21 of document 5 to index.
# Added page 22 of document 5 to index.
# Added page 23 of document 5 to index.
# Added page 24 of document 5 to index.
# Added page 25 of document 5 to index.
# Added page 26 of document 5 to index.
# Added page 27 of document 5 to index.
# Added page 28 of document 5 to index.
# Added page 29 of document 5 to index.
# Added page 30 of document 5 to index.
# Added page 31 of document 5 to index.
# Added page 32 of document 5 to index.
# Added page 33 of document 5 to index.
# Added page 34 of document 5 to index.
# Added page 35 of document 5 to index.
# Added page 36 of document 5 to index.
# Added page 37 of document 5 to index.
# Added page 38 of document 5 to index.
# Added page 39 of document 5 to index.
# Added page 40 of document 5 to index.
# Added page 41 of document 5 to index.
# Added page 42 of document 5 to index.
# Added page 43 of document 5 to index.
# Added page 44 of document 5 to index.
# Added page 45 of document 5 to index.
# Added page 46 of document 5 to index.
# Added page 47 of document 5 to index.
# Added page 48 of document 5 to index.
# Added page 49 of document 5 to index.
# Added page 50 of document 5 to index.
# Added page 51 of document 5 to index.
# Added page 52 of document 5 to index.
# Added page 53 of document 5 to index.
# Added page 54 of document 5 to index.
# Added page 55 of document 5 to index.
# Added page 56 of document 5 to index.
# Added page 57 of document 5 to index.
# Added page 58 of document 5 to index.
# Added page 59 of document 5 to index.
# Added page 60 of document 5 to index.
# Added page 61 of document 5 to index.
# Added page 62 of document 5 to index.
# Added page 63 of document 5 to index.
# Added page 64 of document 5 to index.
# Added page 65 of document 5 to index.
# Added page 66 of document 5 to index.
# Added page 67 of document 5 to index.
# Added page 68 of document 5 to index.
# Added page 69 of document 5 to index.
# Added page 70 of document 5 to index.
# Added page 71 of document 5 to index.
# Added page 72 of document 5 to index.
# Added page 73 of document 5 to index.
# Added page 74 of document 5 to index.
# Added page 75 of document 5 to index.
# Added page 76 of document 5 to index.
# Added page 77 of document 5 to index.
# Added page 78 of document 5 to index.
# Added page 79 of document 5 to index.
# Added page 80 of document 5 to index.
# Added page 81 of document 5 to index.
# Added page 82 of document 5 to index.
# Added page 83 of document 5 to index.
# Added page 84 of document 5 to index.
# Added page 85 of document 5 to index.
# Added page 86 of document 5 to index.
# Added page 87 of document 5 to index.
# Added page 88 of document 5 to index.
# Added page 89 of document 5 to index.
# Added page 90 of document 5 to index.
# Added page 91 of document 5 to index.
# Added page 92 of document 5 to index.
# Added page 93 of document 5 to index.
# Added page 94 of document 5 to index.
# Added page 95 of document 5 to index.
# Added page 96 of document 5 to index.
# Added page 97 of document 5 to index.
# Added page 98 of document 5 to index.
# Added page 99 of document 5 to index.
# Added page 100 of document 5 to index.
# Added page 101 of document 5 to index.
# Added page 102 of document 5 to index.
# Added page 103 of document 5 to index.
# Added page 104 of document 5 to index.
# Added page 105 of document 5 to index.
# Added page 106 of document 5 to index.
# Added page 107 of document 5 to index.
# Added page 108 of document 5 to index.
# Added page 109 of document 5 to index.
# Added page 110 of document 5 to index.
# Added page 111 of document 5 to index.
# Added page 112 of document 5 to index.
# Added page 113 of document 5 to index.
# Added page 114 of document 5 to index.
# Added page 115 of document 5 to index.
# Added page 116 of document 5 to index.
# Added page 117 of document 5 to index.
# Added page 118 of document 5 to index.
# Added page 119 of document 5 to index.
# Added page 120 of document 5 to index.
# Added page 121 of document 5 to index.
# Added page 122 of document 5 to index.
# Added page 123 of document 5 to index.
# Added page 124 of document 5 to index.
# Added page 125 of document 5 to index.
# Added page 126 of document 5 to index.
# Added page 127 of document 5 to index.
# Added page 128 of document 5 to index.
# Added page 129 of document 5 to index.
# Added page 130 of document 5 to index.
# Added page 131 of document 5 to index.
# Added page 132 of document 5 to index.
# Added page 133 of document 5 to index.
# Added page 134 of document 5 to index.
# Added page 135 of document 5 to index.
# Added page 136 of document 5 to index.
# Added page 137 of document 5 to index.
# Added page 138 of document 5 to index.
# Added page 139 of document 5 to index.
# Added page 140 of document 5 to index.
# Added page 141 of document 5 to index.
# Added page 142 of document 5 to index.
# Added page 143 of document 5 to index.
# Added page 144 of document 5 to index.
# Added page 145 of document 5 to index.
# Added page 146 of document 5 to index.
# Added page 147 of document 5 to index.
# Added page 148 of document 5 to index.
# Added page 149 of document 5 to index.
# Added page 150 of document 5 to index.
# Added page 151 of document 5 to index.
# Added page 152 of document 5 to index.
# Added page 153 of document 5 to index.
# Added page 154 of document 5 to index.
# Added page 155 of document 5 to index.
# Added page 156 of document 5 to index.
# Added page 157 of document 5 to index.
# Added page 158 of document 5 to index.
# Added page 159 of document 5 to index.
# Added page 160 of document 5 to index.
# Added page 161 of document 5 to index.
# Added page 162 of document 5 to index.
# Added page 163 of document 5 to index.
# Added page 164 of document 5 to index.
# Added page 165 of document 5 to index.
# Added page 166 of document 5 to index.
# Added page 167 of document 5 to index.
# Added page 168 of document 5 to index.
# Added page 169 of document 5 to index.
# Added page 170 of document 5 to index.
# Added page 171 of document 5 to index.
# Added page 172 of document 5 to index.
# Added page 173 of document 5 to index.
# Added page 174 of document 5 to index.
# Added page 175 of document 5 to index.
# Added page 176 of document 5 to index.
# Added page 177 of document 5 to index.
# Added page 178 of document 5 to index.
# Added page 179 of document 5 to index.
# Added page 180 of document 5 to index.
# Added page 181 of document 5 to index.
# Added page 182 of document 5 to index.
# Added page 183 of document 5 to index.
# Added page 184 of document 5 to index.
# Added page 185 of document 5 to index.
# Added page 186 of document 5 to index.
# Added page 187 of document 5 to index.
# Added page 188 of document 5 to index.
# Added page 189 of document 5 to index.
# Added page 190 of document 5 to index.
# Added page 191 of document 5 to index.
# Added page 192 of document 5 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/McKinsey_Next Big Arenas_2024 (213 pgs).pdf
# Added page 1 of document 6 to index.
# Added page 2 of document 6 to index.
# Added page 3 of document 6 to index.
# Added page 4 of document 6 to index.
# Added page 5 of document 6 to index.
# Added page 6 of document 6 to index.
# Added page 7 of document 6 to index.
# Added page 8 of document 6 to index.
# Added page 9 of document 6 to index.
# Added page 10 of document 6 to index.
# Added page 11 of document 6 to index.
# Added page 12 of document 6 to index.
# Added page 13 of document 6 to index.
# Added page 14 of document 6 to index.
# Added page 15 of document 6 to index.
# Added page 16 of document 6 to index.
# Added page 17 of document 6 to index.
# Added page 18 of document 6 to index.
# Added page 19 of document 6 to index.
# Added page 20 of document 6 to index.
# Added page 21 of document 6 to index.
# Added page 22 of document 6 to index.
# Added page 23 of document 6 to index.
# Added page 24 of document 6 to index.
# Added page 25 of document 6 to index.
# Added page 26 of document 6 to index.
# Added page 27 of document 6 to index.
# Added page 28 of document 6 to index.
# Added page 29 of document 6 to index.
# Added page 30 of document 6 to index.
# Added page 31 of document 6 to index.
# Added page 32 of document 6 to index.
# Added page 33 of document 6 to index.
# Added page 34 of document 6 to index.
# Added page 35 of document 6 to index.
# Added page 36 of document 6 to index.
# Added page 37 of document 6 to index.
# Added page 38 of document 6 to index.
# Added page 39 of document 6 to index.
# Added page 40 of document 6 to index.
# Added page 41 of document 6 to index.
# Added page 42 of document 6 to index.
# Added page 43 of document 6 to index.
# Added page 44 of document 6 to index.
# Added page 45 of document 6 to index.
# Added page 46 of document 6 to index.
# Added page 47 of document 6 to index.
# Added page 48 of document 6 to index.
# Added page 49 of document 6 to index.
# Added page 50 of document 6 to index.
# Added page 51 of document 6 to index.
# Added page 52 of document 6 to index.
# Added page 53 of document 6 to index.
# Added page 54 of document 6 to index.
# Added page 55 of document 6 to index.
# Added page 56 of document 6 to index.
# Added page 57 of document 6 to index.
# Added page 58 of document 6 to index.
# Added page 59 of document 6 to index.
# Added page 60 of document 6 to index.
# Added page 61 of document 6 to index.
# Added page 62 of document 6 to index.
# Added page 63 of document 6 to index.
# Added page 64 of document 6 to index.
# Added page 65 of document 6 to index.
# Added page 66 of document 6 to index.
# Added page 67 of document 6 to index.
# Added page 68 of document 6 to index.
# Added page 69 of document 6 to index.
# Added page 70 of document 6 to index.
# Added page 71 of document 6 to index.
# Added page 72 of document 6 to index.
# Added page 73 of document 6 to index.
# Added page 74 of document 6 to index.
# Added page 75 of document 6 to index.
# Added page 76 of document 6 to index.
# Added page 77 of document 6 to index.
# Added page 78 of document 6 to index.
# Added page 79 of document 6 to index.
# Added page 80 of document 6 to index.
# Added page 81 of document 6 to index.
# Added page 82 of document 6 to index.
# Added page 83 of document 6 to index.
# Added page 84 of document 6 to index.
# Added page 85 of document 6 to index.
# Added page 86 of document 6 to index.
# Added page 87 of document 6 to index.
# Added page 88 of document 6 to index.
# Added page 89 of document 6 to index.
# Added page 90 of document 6 to index.
# Added page 91 of document 6 to index.
# Added page 92 of document 6 to index.
# Added page 93 of document 6 to index.
# Added page 94 of document 6 to index.
# Added page 95 of document 6 to index.
# Added page 96 of document 6 to index.
# Added page 97 of document 6 to index.
# Added page 98 of document 6 to index.
# Added page 99 of document 6 to index.
# Added page 100 of document 6 to index.
# Added page 101 of document 6 to index.
# Added page 102 of document 6 to index.
# Added page 103 of document 6 to index.
# Added page 104 of document 6 to index.
# Added page 105 of document 6 to index.
# Added page 106 of document 6 to index.
# Added page 107 of document 6 to index.
# Added page 108 of document 6 to index.
# Added page 109 of document 6 to index.
# Added page 110 of document 6 to index.
# Added page 111 of document 6 to index.
# Added page 112 of document 6 to index.
# Added page 113 of document 6 to index.
# Added page 114 of document 6 to index.
# Added page 115 of document 6 to index.
# Added page 116 of document 6 to index.
# Added page 117 of document 6 to index.
# Added page 118 of document 6 to index.
# Added page 119 of document 6 to index.
# Added page 120 of document 6 to index.
# Added page 121 of document 6 to index.
# Added page 122 of document 6 to index.
# Added page 123 of document 6 to index.
# Added page 124 of document 6 to index.
# Added page 125 of document 6 to index.
# Added page 126 of document 6 to index.
# Added page 127 of document 6 to index.
# Added page 128 of document 6 to index.
# Added page 129 of document 6 to index.
# Added page 130 of document 6 to index.
# Added page 131 of document 6 to index.
# Added page 132 of document 6 to index.
# Added page 133 of document 6 to index.
# Added page 134 of document 6 to index.
# Added page 135 of document 6 to index.
# Added page 136 of document 6 to index.
# Added page 137 of document 6 to index.
# Added page 138 of document 6 to index.
# Added page 139 of document 6 to index.
# Added page 140 of document 6 to index.
# Added page 141 of document 6 to index.
# Added page 142 of document 6 to index.
# Added page 143 of document 6 to index.
# Added page 144 of document 6 to index.
# Added page 145 of document 6 to index.
# Added page 146 of document 6 to index.
# Added page 147 of document 6 to index.
# Added page 148 of document 6 to index.
# Added page 149 of document 6 to index.
# Added page 150 of document 6 to index.
# Added page 151 of document 6 to index.
# Added page 152 of document 6 to index.
# Added page 153 of document 6 to index.
# Added page 154 of document 6 to index.
# Added page 155 of document 6 to index.
# Added page 156 of document 6 to index.
# Added page 157 of document 6 to index.
# Added page 158 of document 6 to index.
# Added page 159 of document 6 to index.
# Added page 160 of document 6 to index.
# Added page 161 of document 6 to index.
# Added page 162 of document 6 to index.
# Added page 163 of document 6 to index.
# Added page 164 of document 6 to index.
# Added page 165 of document 6 to index.
# Added page 166 of document 6 to index.
# Added page 167 of document 6 to index.
# Added page 168 of document 6 to index.
# Added page 169 of document 6 to index.
# Added page 170 of document 6 to index.
# Added page 171 of document 6 to index.
# Added page 172 of document 6 to index.
# Added page 173 of document 6 to index.
# Added page 174 of document 6 to index.
# Added page 175 of document 6 to index.
# Added page 176 of document 6 to index.
# Added page 177 of document 6 to index.
# Added page 178 of document 6 to index.
# Added page 179 of document 6 to index.
# Added page 180 of document 6 to index.
# Added page 181 of document 6 to index.
# Added page 182 of document 6 to index.
# Added page 183 of document 6 to index.
# Added page 184 of document 6 to index.
# Added page 185 of document 6 to index.
# Added page 186 of document 6 to index.
# Added page 187 of document 6 to index.
# Added page 188 of document 6 to index.
# Added page 189 of document 6 to index.
# Added page 190 of document 6 to index.
# Added page 191 of document 6 to index.
# Added page 192 of document 6 to index.
# Added page 193 of document 6 to index.
# Added page 194 of document 6 to index.
# Added page 195 of document 6 to index.
# Added page 196 of document 6 to index.
# Added page 197 of document 6 to index.
# Added page 198 of document 6 to index.
# Added page 199 of document 6 to index.
# Added page 200 of document 6 to index.
# Added page 201 of document 6 to index.
# Added page 202 of document 6 to index.
# Added page 203 of document 6 to index.
# Added page 204 of document 6 to index.
# Added page 205 of document 6 to index.
# Added page 206 of document 6 to index.
# Added page 207 of document 6 to index.
# Added page 208 of document 6 to index.
# Added page 209 of document 6 to index.
# Added page 210 of document 6 to index.
# Added page 211 of document 6 to index.
# Added page 212 of document 6 to index.
# Added page 213 of document 6 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/NN_AR_2021_Book_RUS_26.09.22.pdf
# Added page 1 of document 7 to index.
# Added page 2 of document 7 to index.
# Added page 3 of document 7 to index.
# Added page 4 of document 7 to index.
# Added page 5 of document 7 to index.
# Added page 6 of document 7 to index.
# Added page 7 of document 7 to index.
# Added page 8 of document 7 to index.
# Added page 9 of document 7 to index.
# Added page 10 of document 7 to index.
# Added page 11 of document 7 to index.
# Added page 12 of document 7 to index.
# Added page 13 of document 7 to index.
# Added page 14 of document 7 to index.
# Added page 15 of document 7 to index.
# Added page 16 of document 7 to index.
# Added page 17 of document 7 to index.
# Added page 18 of document 7 to index.
# Added page 19 of document 7 to index.
# Added page 20 of document 7 to index.
# Added page 21 of document 7 to index.
# Added page 22 of document 7 to index.
# Added page 23 of document 7 to index.
# Added page 24 of document 7 to index.
# Added page 25 of document 7 to index.
# Added page 26 of document 7 to index.
# Added page 27 of document 7 to index.
# Added page 28 of document 7 to index.
# Added page 29 of document 7 to index.
# Added page 30 of document 7 to index.
# Added page 31 of document 7 to index.
# Added page 32 of document 7 to index.
# Added page 33 of document 7 to index.
# Added page 34 of document 7 to index.
# Added page 35 of document 7 to index.
# Added page 36 of document 7 to index.
# Added page 37 of document 7 to index.
# Added page 38 of document 7 to index.
# Added page 39 of document 7 to index.
# Added page 40 of document 7 to index.
# Added page 41 of document 7 to index.
# Added page 42 of document 7 to index.
# Added page 43 of document 7 to index.
# Added page 44 of document 7 to index.
# Added page 45 of document 7 to index.
# Added page 46 of document 7 to index.
# Added page 47 of document 7 to index.
# Added page 48 of document 7 to index.
# Added page 49 of document 7 to index.
# Added page 50 of document 7 to index.
# Added page 51 of document 7 to index.
# Added page 52 of document 7 to index.
# Added page 53 of document 7 to index.
# Added page 54 of document 7 to index.
# Added page 55 of document 7 to index.
# Added page 56 of document 7 to index.
# Added page 57 of document 7 to index.
# Added page 58 of document 7 to index.
# Added page 59 of document 7 to index.
# Added page 60 of document 7 to index.
# Added page 61 of document 7 to index.
# Added page 62 of document 7 to index.
# Added page 63 of document 7 to index.
# Added page 64 of document 7 to index.
# Added page 65 of document 7 to index.
# Added page 66 of document 7 to index.
# Added page 67 of document 7 to index.
# Added page 68 of document 7 to index.
# Added page 69 of document 7 to index.
# Added page 70 of document 7 to index.
# Added page 71 of document 7 to index.
# Added page 72 of document 7 to index.
# Added page 73 of document 7 to index.
# Added page 74 of document 7 to index.
# Added page 75 of document 7 to index.
# Added page 76 of document 7 to index.
# Added page 77 of document 7 to index.
# Added page 78 of document 7 to index.
# Added page 79 of document 7 to index.
# Added page 80 of document 7 to index.
# Added page 81 of document 7 to index.
# Added page 82 of document 7 to index.
# Added page 83 of document 7 to index.
# Added page 84 of document 7 to index.
# Added page 85 of document 7 to index.
# Added page 86 of document 7 to index.
# Added page 87 of document 7 to index.
# Added page 88 of document 7 to index.
# Added page 89 of document 7 to index.
# Added page 90 of document 7 to index.
# Added page 91 of document 7 to index.
# Added page 92 of document 7 to index.
# Added page 93 of document 7 to index.
# Added page 94 of document 7 to index.
# Added page 95 of document 7 to index.
# Added page 96 of document 7 to index.
# Added page 97 of document 7 to index.
# Added page 98 of document 7 to index.
# Added page 99 of document 7 to index.
# Added page 100 of document 7 to index.
# Added page 101 of document 7 to index.
# Added page 102 of document 7 to index.
# Added page 103 of document 7 to index.
# Added page 104 of document 7 to index.
# Added page 105 of document 7 to index.
# Added page 106 of document 7 to index.
# Added page 107 of document 7 to index.
# Added page 108 of document 7 to index.
# Added page 109 of document 7 to index.
# Added page 110 of document 7 to index.
# Added page 111 of document 7 to index.
# Added page 112 of document 7 to index.
# Added page 113 of document 7 to index.
# Added page 114 of document 7 to index.
# Added page 115 of document 7 to index.
# Added page 116 of document 7 to index.
# Added page 117 of document 7 to index.
# Added page 118 of document 7 to index.
# Added page 119 of document 7 to index.
# Added page 120 of document 7 to index.
# Added page 121 of document 7 to index.
# Added page 122 of document 7 to index.
# Added page 123 of document 7 to index.
# Added page 124 of document 7 to index.
# Added page 125 of document 7 to index.
# Added page 126 of document 7 to index.
# Added page 127 of document 7 to index.
# Added page 128 of document 7 to index.
# Added page 129 of document 7 to index.
# Added page 130 of document 7 to index.
# Added page 131 of document 7 to index.
# Added page 132 of document 7 to index.
# Added page 133 of document 7 to index.
# Added page 134 of document 7 to index.
# Added page 135 of document 7 to index.
# Added page 136 of document 7 to index.
# Added page 137 of document 7 to index.
# Added page 138 of document 7 to index.
# Added page 139 of document 7 to index.
# Added page 140 of document 7 to index.
# Added page 141 of document 7 to index.
# Added page 142 of document 7 to index.
# ...
# Added page 161 of document 20 to index.
# Added page 162 of document 20 to index.
# Added page 163 of document 20 to index.
# Added page 164 of document 20 to index.
# Added page 165 of document 20 to index.
# Added page 166 of document 20 to index.
# Added page 167 of document 20 to index.
# Added page 168 of document 20 to index.
# Added page 169 of document 20 to index.
# Added page 170 of document 20 to index.
# Added page 171 of document 20 to index.
# Added page 172 of document 20 to index.
# Added page 173 of document 20 to index.
# Added page 174 of document 20 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/K2Tex_x_Teä«_É«ßß¿⌐ß¬¿⌐_αδ¡«¬_êÆ_2024_30_ßΓα.pdf
# Added page 1 of document 21 to index.
# Added page 2 of document 21 to index.
# Added page 3 of document 21 to index.
# Added page 4 of document 21 to index.
# Added page 5 of document 21 to index.
# Added page 6 of document 21 to index.
# Added page 7 of document 21 to index.
# Added page 8 of document 21 to index.
# Added page 9 of document 21 to index.
# Added page 10 of document 21 to index.
# Added page 11 of document 21 to index.
# Added page 12 of document 21 to index.
# Added page 13 of document 21 to index.
# Added page 14 of document 21 to index.
# Added page 15 of document 21 to index.
# Added page 16 of document 21 to index.
# Added page 17 of document 21 to index.
# Added page 18 of document 21 to index.
# Added page 19 of document 21 to index.
# Added page 20 of document 21 to index.
# Added page 21 of document 21 to index.
# Added page 22 of document 21 to index.
# Added page 23 of document 21 to index.
# Added page 24 of document 21 to index.
# Added page 25 of document 21 to index.
# Added page 26 of document 21 to index.
# Added page 27 of document 21 to index.
# Added page 28 of document 21 to index.
# Added page 29 of document 21 to index.
# Added page 30 of document 21 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/2_5282802846297776741.pdf
# Added page 1 of document 22 to index.
# Added page 2 of document 22 to index.
# Added page 3 of document 22 to index.
# Added page 4 of document 22 to index.
# Added page 5 of document 22 to index.
# Added page 6 of document 22 to index.
# Added page 7 of document 22 to index.
# Added page 8 of document 22 to index.
# Added page 9 of document 22 to index.
# Added page 10 of document 22 to index.
# Added page 11 of document 22 to index.
# Added page 12 of document 22 to index.
# Added page 13 of document 22 to index.
# Added page 14 of document 22 to index.
# Added page 15 of document 22 to index.
# Added page 16 of document 22 to index.
# Added page 17 of document 22 to index.
# Added page 18 of document 22 to index.
# Added page 19 of document 22 to index.
# Added page 20 of document 22 to index.
# Added page 21 of document 22 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/nn_climate_change_report_rus.pdf
# Added page 1 of document 23 to index.
# Added page 2 of document 23 to index.
# Added page 3 of document 23 to index.
# Added page 4 of document 23 to index.
# Added page 5 of document 23 to index.
# Added page 6 of document 23 to index.
# Added page 7 of document 23 to index.
# Added page 8 of document 23 to index.
# Added page 9 of document 23 to index.
# Added page 10 of document 23 to index.
# Added page 11 of document 23 to index.
# Added page 12 of document 23 to index.
# Added page 13 of document 23 to index.
# Added page 14 of document 23 to index.
# Added page 15 of document 23 to index.
# Added page 16 of document 23 to index.
# Added page 17 of document 23 to index.
# Added page 18 of document 23 to index.
# Added page 19 of document 23 to index.
# Added page 20 of document 23 to index.
# Added page 21 of document 23 to index.
# Added page 22 of document 23 to index.
# Added page 23 of document 23 to index.
# Added page 24 of document 23 to index.
# Added page 25 of document 23 to index.
# Added page 26 of document 23 to index.
# Added page 27 of document 23 to index.
# Added page 28 of document 23 to index.
# Added page 29 of document 23 to index.
# Added page 30 of document 23 to index.
# Added page 31 of document 23 to index.
# Added page 32 of document 23 to index.
# Added page 33 of document 23 to index.
# Added page 34 of document 23 to index.
# Added page 35 of document 23 to index.
# Added page 36 of document 23 to index.
# Added page 37 of document 23 to index.
# Added page 38 of document 23 to index.
# Added page 39 of document 23 to index.
# Index exported to /content/indices/testindex1
# Indexing file: /content/pdf_files/nn_cso_2023_rus.pdf
# Added page 1 of document 24 to index.
# Added page 2 of document 24 to index.
# Added page 3 of document 24 to index.
# Added page 4 of document 24 to index.
# Added page 5 of document 24 to index.
# Added page 6 of document 24 to index.
# Added page 7 of document 24 to index.
# Added page 8 of document 24 to index.
# Added page 9 of document 24 to index.
# Added page 10 of document 24 to index.
# Added page 11 of document 24 to index.
# Added page 12 of document 24 to index.
# Added page 13 of document 24 to index.
# Added page 14 of document 24 to index.
# Added page 15 of document 24 to index.
# Added page 16 of document 24 to index.
# Added page 17 of document 24 to index.
# Added page 18 of document 24 to index.
# Added page 19 of document 24 to index.
# Added page 20 of document 24 to index.
# Added page 21 of document 24 to index.
# Added page 22 of document 24 to index.
# Added page 23 of document 24 to index.
# Added page 24 of document 24 to index.
# Added page 25 of document 24 to index.
# Added page 26 of document 24 to index.
# Added page 27 of document 24 to index.
# Added page 28 of document 24 to index.
# Added page 29 of document 24 to index.
# Added page 30 of document 24 to index.
# Added page 31 of document 24 to index.
# Added page 32 of document 24 to index.
# Added page 33 of document 24 to index.
# Added page 34 of document 24 to index.
# Added page 35 of document 24 to index.
# Added page 36 of document 24 to index.
# Added page 37 of document 24 to index.
# Added page 38 of document 24 to index.
# Added page 39 of document 24 to index.
# Added page 40 of document 24 to index.
# Added page 41 of document 24 to index.
# Added page 42 of document 24 to index.
# Added page 43 of document 24 to index.
# Added page 44 of document 24 to index.
# Added page 45 of document 24 to index.
# Added page 46 of document 24 to index.
# Added page 47 of document 24 to index.
# Added page 48 of document 24 to index.
# Added page 49 of document 24 to index.
# Added page 50 of document 24 to index.
# Added page 51 of document 24 to index.
# Added page 52 of document 24 to index.
# Added page 53 of document 24 to index.
# Added page 54 of document 24 to index.
# Added page 55 of document 24 to index.
# Added page 56 of document 24 to index.
# Added page 57 of document 24 to index.
# Added page 58 of document 24 to index.
# Added page 59 of document 24 to index.
# Added page 60 of document 24 to index.
# Added page 61 of document 24 to index.
# Added page 62 of document 24 to index.
# Added page 63 of document 24 to index.
# Added page 64 of document 24 to index.
# Added page 65 of document 24 to index.
# Added page 66 of document 24 to index.
# Added page 67 of document 24 to index.
# Added page 68 of document 24 to index.
# Added page 69 of document 24 to index.
# Added page 70 of document 24 to index.
# Added page 71 of document 24 to index.
# Added page 72 of document 24 to index.
# Added page 73 of document 24 to index.
# Added page 74 of document 24 to index.
# Added page 75 of document 24 to index.
# Added page 76 of document 24 to index.
# Added page 77 of document 24 to index.
# Added page 78 of document 24 to index.
# Added page 79 of document 24 to index.
# Added page 80 of document 24 to index.
# Added page 81 of document 24 to index.
# Added page 82 of document 24 to index.
# Added page 83 of document 24 to index.
# Added page 84 of document 24 to index.
# Added page 85 of document 24 to index.
# Added page 86 of document 24 to index.
# Added page 87 of document 24 to index.
# Added page 88 of document 24 to index.
# Added page 89 of document 24 to index.
# Added page 90 of document 24 to index.
# Added page 91 of document 24 to index.
# Added page 92 of document 24 to index.
# Added page 93 of document 24 to index.
# Added page 94 of document 24 to index.
# Added page 95 of document 24 to index.
# Added page 96 of document 24 to index.
# Added page 97 of document 24 to index.
# Added page 98 of document 24 to index.
# Added page 99 of document 24 to index.
# Added page 100 of document 24 to index.
# Added page 101 of document 24 to index.
# Added page 102 of document 24 to index.
# Added page 103 of document 24 to index.
# Added page 104 of document 24 to index.
# Added page 105 of document 24 to index.
# Added page 106 of document 24 to index.
# Added page 107 of document 24 to index.
# Added page 108 of document 24 to index.
# Added page 109 of document 24 to index.
# Added page 110 of document 24 to index.
# Added page 111 of document 24 to index.
# Added page 112 of document 24 to index.
# Added page 113 of document 24 to index.
# Added page 114 of document 24 to index.
# Added page 115 of document 24 to index.
# Added page 116 of document 24 to index.
# Added page 117 of document 24 to index.
# Added page 118 of document 24 to index.
# Added page 119 of document 24 to index.
# Added page 120 of document 24 to index.
# Added page 121 of document 24 to index.
# Added page 122 of document 24 to index.
# Added page 123 of document 24 to index.
# Added page 124 of document 24 to index.
# Added page 125 of document 24 to index.
# Added page 126 of document 24 to index.
# Added page 127 of document 24 to index.
# Added page 128 of document 24 to index.
# Added page 129 of document 24 to index.
# Added page 130 of document 24 to index.
# Added page 131 of document 24 to index.
# Added page 132 of document 24 to index.
# Added page 133 of document 24 to index.
# Added page 134 of document 24 to index.
# Added page 135 of document 24 to index.
# Added page 136 of document 24 to index.
# Added page 137 of document 24 to index.
# Added page 138 of document 24 to index.
# Added page 139 of document 24 to index.
# Added page 140 of document 24 to index.
# Added page 141 of document 24 to index.
# Added page 142 of document 24 to index.
# Added page 143 of document 24 to index.
# Added page 144 of document 24 to index.
# Added page 145 of document 24 to index.
# Added page 146 of document 24 to index.
# Added page 147 of document 24 to index.
# Added page 148 of document 24 to index.
# Added page 149 of document 24 to index.
# Added page 150 of document 24 to index.
# Added page 151 of document 24 to index.
# Added page 152 of document 24 to index.
# Added page 153 of document 24 to index.
# Added page 154 of document 24 to index.
# Added page 155 of document 24 to index.
# Added page 156 of document 24 to index.
# Added page 157 of document 24 to index.
# Added page 158 of document 24 to index.
# Added page 159 of document 24 to index.
# Added page 160 of document 24 to index.
# Added page 161 of document 24 to index.
# Added page 162 of document 24 to index.
# Added page 163 of document 24 to index.
# Added page 164 of document 24 to index.
# Added page 165 of document 24 to index.
# Added page 166 of document 24 to index.
# Added page 167 of document 24 to index.
# Added page 168 of document 24 to index.
# Added page 169 of document 24 to index.
# Added page 170 of document 24 to index.
# Added page 171 of document 24 to index.
# Added page 172 of document 24 to index.
# Added page 173 of document 24 to index.
# Added page 174 of document 24 to index.
# Added page 175 of document 24 to index.
# Added page 176 of document 24 to index.
# Added page 177 of document 24 to index.
# Added page 178 of document 24 to index.
# Added page 179 of document 24 to index.
# Added page 180 of document 24 to index.
# Added page 181 of document 24 to index.
# Added page 182 of document 24 to index.
# Added page 183 of document 24 to index.
# Added page 184 of document 24 to index.
# Added page 185 of document 24 to index.
# Added page 186 of document 24 to index.
# Added page 187 of document 24 to index.
# Added page 188 of document 24 to index.
# Added page 189 of document 24 to index.
# Added page 190 of document 24 to index.
# Added page 191 of document 24 to index.
# Added page 192 of document 24 to index.
# Added page 193 of document 24 to index.
# Added page 194 of document 24 to index.
# Added page 195 of document 24 to index.
# Added page 196 of document 24 to index.
# Added page 197 of document 24 to index.
# Added page 198 of document 24 to index.
# Added page 199 of document 24 to index.
# Added page 200 of document 24 to index.
# Added page 201 of document 24 to index.
# Added page 202 of document 24 to index.
# Added page 203 of document 24 to index.
# Added page 204 of document 24 to index.
# Added page 205 of document 24 to index.
# Added page 206 of document 24 to index.
# Added page 207 of document 24 to index.
# Added page 208 of document 24 to index.
# Added page 209 of document 24 to index.
# Added page 210 of document 24 to index.
# Added page 211 of document 24 to index.
# Added page 212 of document 24 to index.
# Added page 213 of document 24 to index.
# Added page 214 of document 24 to index.
# Added page 215 of document 24 to index.
# Added page 216 of document 24 to index.
# Added page 217 of document 24 to index.
# Added page 218 of document 24 to index.
# Added page 219 of document 24 to index.
# Added page 220 of document 24 to index.
# Added page 221 of document 24 to index.
# Added page 222 of document 24 to index.
# Added page 223 of document 24 to index.
# Added page 224 of document 24 to index.
# Added page 225 of document 24 to index.
# Added page 226 of document 24 to index.
# Added page 227 of document 24 to index.
# Added page 228 of document 24 to index.
# Added page 229 of document 24 to index.
# Added page 230 of document 24 to index.
# Added page 231 of document 24 to index.
# Added page 232 of document 24 to index.
# Added page 233 of document 24 to index.
# Added page 234 of document 24 to index.
# Added page 235 of document 24 to index.
# Added page 236 of document 24 to index.
# Added page 237 of document 24 to index.
# Added page 238 of document 24 to index.
# Added page 239 of document 24 to index.
# Added page 240 of document 24 to index.
# Added page 241 of document 24 to index.
# Added page 242 of document 24 to index.
# Added page 243 of document 24 to index.
# Added page 244 of document 24 to index.
# Added page 245 of document 24 to index.
# Added page 246 of document 24 to index.
# Index exported to /content/indices/testindex1
# Index exported to /content/indices/testindex1
# {0: '/content/pdf_files/sr_ru_annual_report_pages_nornik_2022.pdf',
#  1: '/content/pdf_files/responsible_supply_chain_report_rus.pdf',
#  2: '/content/pdf_files/NN_CSO2021_RUS_03.03.2023.pdf',
#  3: '/content/pdf_files/2_5366183129474161642.pdf',
#  4: '/content/pdf_files/digital_production_5.pdf',
#  5: '/content/pdf_files/2022_Annual_Report_of_PJSC_MMC_Norilsk_Nickel_rus.pdf',
#  6: '/content/pdf_files/McKinsey_Next Big Arenas_2024 (213 pgs).pdf',
#  7: '/content/pdf_files/NN_AR_2021_Book_RUS_26.09.22.pdf',
#  8: '/content/pdf_files/îîè 2024.pdf',
#  9: '/content/pdf_files/ìïîè 2024.pdf',
#  10: '/content/pdf_files/KPMG_Global Metals & Mining_2024 (48 pgs).pdf',
#  11: '/content/pdf_files/Kept_Äíº«α_µÑ¡_ó_¼ÑΓá½½παú¿τÑß¬«⌐_«Γαáß½¿_2è2024.pdf',
#  12: '/content/pdf_files/É«ß¬«¡úαÑßß_Éδ¡«¬_»α«¼δΦ½Ñ¡¡δσ_α«í«Γ«ó_ó_¼¿αÑ_¿_É«ßß¿¿_2024_16_ßΓα.pdf',
#  13: '/content/pdf_files/ä«¬½áñ, πú«½∞ τáßΓ∞ 1.pdf',
#  14: '/content/pdf_files/û¿Σα«ó¿ºáµ¿∩_ú«α¡«_¼ÑΓá½½παú¿τÑß¬«⌐_«Γαáß½¿_É«ßß¿¿_ó_2024_ú_.pdf',
#  15: '/content/pdf_files/Kept_ç«½«Γ«ñ«íδóáεΘ¿Ñ_¬«¼»á¡¿¿_2024_25_ßΓα.pdf',
#  16: '/content/pdf_files/ÆÑä«_¿_æô¥è_ÅÑαß»Ñ¬Γ¿óδ_αáºó¿Γ¿∩_φ¬ß»«αΓá_α«ßß¿⌐ß¬«ú«_πú½∩_202.pdf',
#  17: '/content/pdf_files/ì«α¡¿¬Ñ½∞ »α« ¬«α» ¬π½∞Γπαπ.pdf',
#  18: '/content/pdf_files/ì«α¡¿¬Ñ½∞_é¡πΓαÑ¡¡∩_µÑ¡á_¡á_πú½Ñα«ñ.pdf',
#  19: '/content/pdf_files/Alrosa_Äíº«α_αδ¡¬á_¿¡óÑßΓ¿µ¿«¡¡δσ_íα¿½½¿á¡Γ«ó_«¬Γ∩íα∞_2024.pdf',
#  20: '/content/pdf_files/Godovoi_-otchet-PAO-GMK-Norilskii_-nikel-za-2023-god.pdf',
#  21: '/content/pdf_files/K2Tex_x_Teä«_É«ßß¿⌐ß¬¿⌐_αδ¡«¬_êÆ_2024_30_ßΓα.pdf',
#  22: '/content/pdf_files/2_5282802846297776741.pdf',
#  23: '/content/pdf_files/nn_climate_change_report_rus.pdf',
#  24: '/content/pdf_files/nn_cso_2023_rus.pdf'}

# %%
results = RAG.search('Какой прогноз роста производства продукции компании Норникель к 2030?', k=5)

# %%
results
# Out:
# [{'doc_id': 24, 'page_num': 10, 'score': 30.25, 'metadata': {}, 'base64': None},
#  {'doc_id': 0, 'page_num': 7, 'score': 29.875, 'metadata': {}, 'base64': None},
#  {'doc_id': 20, 'page_num': 1, 'score': 29.75, 'metadata': {}, 'base64': None},
#  {'doc_id': 7, 'page_num': 22, 'score': 29.75, 'metadata': {}, 'base64': None},
#  {'doc_id': 23, 'page_num': 3, 'score': 29.625, 'metadata': {}, 'base64': None}]

# %%
def zip_folder(folder_path, output_zip_path):
    with zipfile.ZipFile(output_zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                # Полный путь к файлу
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, folder_path))

folder_to_zip = '/content/indices/testindex1'
output_zip_file = 'rag.zip'  # Имя выходного ZIP-файла

zip_folder(folder_to_zip, output_zip_file)
print(f"Папка '{folder_to_zip}' успешно заархивирована в '{output_zip_file}'")
# Out:
# Папка '/content/indices/testindex1' успешно заархивирована в 'rag.zip'
